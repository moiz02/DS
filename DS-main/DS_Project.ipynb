# %% [markdown]
# <a href="https://colab.research.google.com/github/moiz02/DS/blob/main/DS-main/DS_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/moiz02/DS/main/LoanApprovalPrediction.csv")

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df["Gender"]=le.fit_transform(df["Gender"])

# %%
df["Gender"].value_counts()
# Out:
# 1    489
# 0    112
# 2     13
# Name: Gender, dtype: int64

# %%
df['Gender'].fillna(value=df['Gender'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Married"]=le.fit_transform(df["Married"])

# %%
df['Married'].fillna(value=df['Married'].mean(),inplace=True)

# %%
df["Dependents"]=le.fit_transform(df["Dependents"])

df['Dependents'].fillna(value=df['Dependents'].mean(),inplace=True)

# %%
df["Self_Employed"]=le.fit_transform(df["Self_Employed"])

df['Self_Employed'].fillna(value=df['Self_Employed'].mean(),inplace=True)

# %%
df["LoanAmount"]=le.fit_transform(df["LoanAmount"])

df['LoanAmount'].fillna(value=df['LoanAmount'].mean(),inplace=True)

# %%
df["Loan_Amount_Term"]=le.fit_transform(df["Loan_Amount_Term"])

df['Loan_Amount_Term'].fillna(value=df['Loan_Amount_Term'].mean(),inplace=True)

# %%
df["Credit_History"]=le.fit_transform(df["Credit_History"])

df['Credit_History'].fillna(value=df['Credit_History'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df["Credit_History"].value_counts()
# Out:
# 1    475
# 0     89
# 2     50
# Name: Credit_History, dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
df=df.drop(["Gender","Married"],axis=1)

# %%
df=df.drop(["Loan_ID"],axis=1)

# %%
import seaborn as sns

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df, bins=5)
# Out:
# (array([[614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [591.,  16.,   4.,   2.,   1.],
#         [610.,   2.,   2.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.],
#         [614.,   0.,   0.,   0.,   0.]]),
#  array([    0., 16200., 32400., 48600., 64800., 81000.]),
#  <a list of 10 BarContainer objects>)

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb1d644c880>,
#  <matplotlib.lines.Line2D at 0x7fb1d644f760>,
#  <matplotlib.lines.Line2D at 0x7fb1d644ed40>,
#  <matplotlib.lines.Line2D at 0x7fb1d644d030>,
#  <matplotlib.lines.Line2D at 0x7fb1d644cee0>,
#  <matplotlib.lines.Line2D at 0x7fb1d644e7d0>,
#  <matplotlib.lines.Line2D at 0x7fb1d644f730>,
#  <matplotlib.lines.Line2D at 0x7fb1d644e920>,
#  <matplotlib.lines.Line2D at 0x7fb1d644da20>,
#  <matplotlib.lines.Line2D at 0x7fb1d644cfd0>]

# %%
sns.boxplot(df)
sns.set(rc={'figure.figsize':(30, 200)})

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
import statsmodels.formula.api as smf

# %%
df.columns
# Out:
# Index(['Dependents', 'Education', 'Self_Employed', 'ApplicantIncome',
#        'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df["Education"]=le.fit_transform(df["Education"])

df['Education'].fillna(value=df['Education'].mean(),inplace=True)

# %%
df["Property_Area"]=le.fit_transform(df["Property_Area"])

df['Property_Area'].fillna(value=df['Property_Area'].mean(),inplace=True)

# %%
df["Loan_Status"]=le.fit_transform(df["Loan_Status"])

df['Loan_Status'].fillna(value=df['Loan_Status'].mean(),inplace=True)

# %%
df.dtypes
# Out:
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount             int64
# Loan_Amount_Term       int64
# Credit_History         int64
# Property_Area          int64
# Loan_Status            int64
# dtype: object

# %%
y=df["Loan_Status"]
x=df.drop(["Loan_Status"],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=5)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(max_leaf_nodes=25)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=25)

# %%
model.score(x_train,y_train)
# Out:
# 0.8656429942418427

# %%
model.score(x_test,y_test)
# Out:
# 0.8279569892473119
