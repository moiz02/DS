# %% [markdown]
# <a href="https://colab.research.google.com/github/moiz02/DS/blob/main/Modified_Project_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/moiz02/DS/main/LoanApprovalPrediction.csv")

# %%
df.head(15)
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0   LP001002   Male      No          0      Graduate            No
# 1   LP001003   Male     Yes          1      Graduate            No
# 2   LP001005   Male     Yes          0      Graduate           Yes
# 3   LP001006   Male     Yes          0  Not Graduate            No
# 4   LP001008   Male      No          0      Graduate            No
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 6   LP001013   Male     Yes          0  Not Graduate            No
# 7   LP001014   Male     Yes         3+      Graduate            No
# 8   LP001018   Male     Yes          2      Graduate            No
# 9   LP001020   Male     Yes          1      Graduate            No
# 10  LP001024   Male     Yes          2      Graduate            No
# 11  LP001027   Male     Yes          2      Graduate           NaN
# 12  LP001028   Male     Yes          2      Graduate            No
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df["Gender"]=le.fit_transform(df["Gender"])

# %%
df["Gender"].value_counts()
# Out:
# 1    489
# 0    112
# 2     13
# Name: Gender, dtype: int64

# %%
df['Gender'].fillna(value=df['Gender'].mean(),inplace=True)

# %%
df["CoapplicantIncome"]=le.fit_transform(df["CoapplicantIncome"])

# %%
df["CoapplicantIncome"].value_counts()
# Out:
# 0      273
# 173      5
# 130      5
# 77       5
# 149      3
#       ...
# 186      1
# 22       1
# 80       1
# 180      1
# 3        1
# Name: CoapplicantIncome, Length: 287, dtype: int64

# %%
df['CoapplicantIncome'].fillna(value=df['CoapplicantIncome'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Married"]=le.fit_transform(df["Married"])

# %%
df['Married'].fillna(value=df['Married'].mean(),inplace=True)

# %%
df["Dependents"]=le.fit_transform(df["Dependents"])

df['Dependents'].fillna(value=df['Dependents'].mean(),inplace=True)

# %%
df["Self_Employed"]=le.fit_transform(df["Self_Employed"])

df['Self_Employed'].fillna(value=df['Self_Employed'].mean(),inplace=True)

# %%
df["LoanAmount"]=le.fit_transform(df["LoanAmount"])

df['LoanAmount'].fillna(value=df['LoanAmount'].mean(),inplace=True)

# %%
df["Loan_Amount_Term"]=le.fit_transform(df["Loan_Amount_Term"])

df['Loan_Amount_Term'].fillna(value=df['Loan_Amount_Term'].mean(),inplace=True)

# %%
df["Credit_History"]=le.fit_transform(df["Credit_History"])

df['Credit_History'].fillna(value=df['Credit_History'].mean(),inplace=True)

# %%
df=df.drop(["Loan_ID"],axis=1)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# %%
df['DebtToIncomeRatio'] = df['TotalIncome'] / df['LoanAmount']

# %%
df['LoanToIncomeRatio'] = df['LoanAmount'] / df['TotalIncome']

# %%
df['RepaymentCapacity'] = df['TotalIncome'] / (df['LoanAmount'] / df['Loan_Amount_Term'])

# %%
df['LoanToMonthlyIncomeRatio'] = df['LoanAmount'] / (df['TotalIncome'] / 12)

# %%
import seaborn as sns

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.regplot(x=df["ApplicantIncome"],y=df['CoapplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='CoapplicantIncome'>

# %%
sns.pairplot(df)

# %%
df["Credit_History"].value_counts()
# Out:
# 1    475
# 0     89
# 2     50
# Name: Credit_History, dtype: int64

# %%
import statsmodels.formula.api as smf

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'DebtToIncomeRatio', 'LoanToIncomeRatio',
#        'RepaymentCapacity', 'LoanToMonthlyIncomeRatio'],
#       dtype='object')

# %%
df["Education"]=le.fit_transform(df["Education"])

df['Education'].fillna(value=df['Education'].mean(),inplace=True)

# %%
df["Property_Area"]=le.fit_transform(df["Property_Area"])

df['Property_Area'].fillna(value=df['Property_Area'].mean(),inplace=True)

# %%
df["Loan_Status"]=le.fit_transform(df["Loan_Status"])

df['Loan_Status'].fillna(value=df['Loan_Status'].mean(),inplace=True)

# %%
df["TotalIncome"]=le.fit_transform(df["TotalIncome"])

df['TotalIncome'].fillna(value=df['TotalIncome'].mean(),inplace=True)

# %%
df["DebtToIncomeRatio"]=le.fit_transform(df["DebtToIncomeRatio"])

df['DebtToIncomeRatio'].fillna(value=df['DebtToIncomeRatio'].mean(),inplace=True)

# %%
df["LoanToIncomeRatio"]=le.fit_transform(df["LoanToIncomeRatio"])

df['LoanToIncomeRatio'].fillna(value=df['LoanToIncomeRatio'].mean(),inplace=True)

# %%
df["RepaymentCapacity"]=le.fit_transform(df["RepaymentCapacity"])

df['RepaymentCapacity'].fillna(value=df['RepaymentCapacity'].mean(),inplace=True)

# %%
df["LoanToMonthlyIncomeRatio"]=le.fit_transform(df["LoanToMonthlyIncomeRatio"])

df['LoanToMonthlyIncomeRatio'].fillna(value=df['LoanToMonthlyIncomeRatio'].mean(),inplace=True)

# %%
df.dtypes
# Out:
# Gender                      int64
# Married                     int64
# Dependents                  int64
# Education                   int64
# Self_Employed               int64
# ApplicantIncome             int64
# CoapplicantIncome           int64
# LoanAmount                  int64
# Loan_Amount_Term            int64
# Credit_History              int64
# Property_Area               int64
# Loan_Status                 int64
# TotalIncome                 int64
# DebtToIncomeRatio           int64
# LoanToIncomeRatio           int64
# RepaymentCapacity           int64
# LoanToMonthlyIncomeRatio    int64
# dtype: object

# %%
model=smf.ols("Loan_Status~Gender+Married+Dependents+Education+Self_Employed+ApplicantIncome+CoapplicantIncome+LoanAmount+Loan_Amount_Term+Credit_History+Property_Area+TotalIncome+DebtToIncomeRatio+LoanToIncomeRatio+RepaymentCapacity+LoanToMonthlyIncomeRatio",data=df).fit()

# %%
model.params
# Out:
# Intercept                  -0.000144
# Gender                      0.002271
# Married                     0.083183
# Dependents                  0.004404
# Education                  -0.090508
# Self_Employed              -0.021244
# ApplicantIncome             0.000008
# CoapplicantIncome          -0.000073
# LoanAmount                 -0.002605
# Loan_Amount_Term            0.004863
# Credit_History              0.419220
# Property_Area               0.013122
# TotalIncome                 0.000312
# DebtToIncomeRatio           0.000270
# LoanToIncomeRatio          -0.087669
# RepaymentCapacity          -0.000060
# LoanToMonthlyIncomeRatio    0.088256
# dtype: float64

# %%
x=[100]
df2=pd.DataFrame(x,columns=["Gender"])
df3=pd.DataFrame(x,columns=["Married"])
df4=pd.DataFrame(x,columns=["Dependents"])
df5=pd.DataFrame(x,columns=["Education"])
df6=pd.DataFrame(x,columns=["Self_Employed"])
df7=pd.DataFrame(x,columns=["ApplicantIncome"])
df8=pd.DataFrame(x,columns=["CoapplicantIncome"])
df9=pd.DataFrame(x,columns=["LoanAmount"])
df10=pd.DataFrame(x,columns=["Loan_Amount_Term"])
df11=pd.DataFrame(x,columns=["Credit_History"])
df12=pd.DataFrame(x,columns=["Property_Area"])
df13=pd.DataFrame(x,columns=["DebtToIncomeRatio"])
df14=pd.DataFrame(x,columns=["LoanToIncomeRatio"])
df15=pd.DataFrame(x,columns=["RepaymentCapacity"])
df16=pd.DataFrame(x,columns=["LoanToMonthlyIncomeRatio"])
df17=pd.DataFrame(x,columns=["TotalIncome"])

# %%
df18=pd.concat([df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17],axis=1)

# %%
model.predict(df18)
# Out:
# 0    41.375131
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Loan_Status   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     10.95
# Date:                Mon, 05 Jun 2023   Prob (F-statistic):           1.11e-23
# Time:                        16:21:14   Log-Likelihood:                -324.72
# No. Observations:                 614   AIC:                             681.4
# Df Residuals:                     598   BIC:                             752.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
x=df[["Gender","Married","Dependents","Education","Self_Employed","ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History","Property_Area","TotalIncome","DebtToIncomeRatio","LoanToIncomeRatio","RepaymentCapacity","LoanToMonthlyIncomeRatio"]]
df19=pd.DataFrame(x,columns=["Gender","Married","Dependents","Education","Self_Employed","ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History","Property_Area","TotalIncome","DebtToIncomeRatio","LoanToIncomeRatio","RepaymentCapacity","LoanToMonthlyIncomeRatio"])
data_pred=model.predict(df19)

# %%
from sklearn import metrics

# %%
mse=metrics.mean_squared_error(df["Loan_Status"],data_pred)
from math import sqrt

# %%
rmse=sqrt(mse)
print(rmse)
# Out:
# 0.41062090061863105

# %%
y=df["Loan_Status"]
x=df.drop(["Loan_Status"],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=5)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
y_pred=model.predict(x_test)

# %%
model=DecisionTreeClassifier(max_leaf_nodes=25)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=25)

# %%
model.score(x_train,y_train)
# Out:
# 0.8752399232245681

# %%
model.score(x_test,y_test)
# Out:
# 0.7741935483870968

# %%
from sklearn import tree

# %%
tree.plot_tree(model)
# Out:
# [Text(0.38839285714285715, 0.9545454545454546, 'x[9] <= 0.5\ngini = 0.431\nsamples = 521\nvalue = [164, 357]'),
#  Text(0.35267857142857145, 0.8636363636363636, 'gini = 0.163\nsamples = 78\nvalue = [71, 7]'),
#  Text(0.42410714285714285, 0.8636363636363636, 'x[14] <= 27.0\ngini = 0.332\nsamples = 443\nvalue = [93, 350]'),
#  Text(0.16071428571428573, 0.7727272727272727, 'x[8] <= 6.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.07142857142857142, 0.6818181818181818, 'x[14] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.03571428571428571, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10714285714285714, 0.5909090909090909, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.25, 0.6818181818181818, 'x[2] <= 1.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.17857142857142858, 0.5909090909090909, 'x[11] <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
# ...
